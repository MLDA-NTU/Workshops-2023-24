# %% [markdown]
# # Introduction
#
# Welcome to the final exercise in this workshop. Congratulations on making it this far! Oppenheimer once said  **"Theory will only take you so far"** so this activity will mostly be about applying the skills that you have learned today. Within each cell is an activity that you will need to do. Some cells will also have hints!

# %% [markdown]
# # Mission
#
# The housing market has been in a wreck for the past few months and people are indecisive over whether to buy a new house or wait until prices go lower. You have been hired as the data-scientist to solve their problem. Using the power of **Regression Analysis**, you believe that you can complete the task

# %% [markdown]
# ## Dataset
#
# Luckily, you have been provided with the historical data for the houses as shown below. Your job is to determine if the house is selling at a bargain price or not based on a few parameters:
#
# * Area of house
# * Number of bedrooms
# * Number of bathrooms
# * Wether it has a basement
#
#
#
# ---
#
# ## Housing Prices
# https://www.kaggle.com/datasets/yasserh/housing-prices-dataset
#
# ## Getting the dataset
# - Don't use the "Download 5kb" button
# - Scroll down to the Housing.csv and download using the "arrow down" button
# - It will be downloaded locally
# - In the google colab on the Left tab, press the folder icon
# - This is the storage location for the Google Colab
# - Drag and drop the Housing.csv to upload

# %% [markdown]
# # Importing the essential 3
#
# In the coming code block import the essential 3 libraries **and seaborn**

# %% [markdown]
# # Data Importing
# In this section, try to import the downloaded dataset on Kaggle into the code base
#
# **Hint: - https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html**

# %% [markdown]
# # Data Preprocessing
#
# The best practice is always to see your data before processing it. Use the below code cell to show the top 5 data-points.
#
# **Hint:-https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html**

# %% [markdown]
# ## Viewing your data

# %% [markdown]
# ## Extracting The Necessary Parameters
#
# Okay now that you have seen the variables of your data, I want you to extract the necessary features, just to remind you, they are the ones below:
#
# * Area of house
# * Number of bedrooms
# * Number of bathrooms
# * Wether it has a basement
#
# Will you use **loc** or **iloc**?
#
# **Hint 1:- https://pandas.pydata.org/docs/index.html**

# %% [markdown]
# ## Data Cleaning
#
# Are all the variables in your analysis numerical, i.e., have numbers? Convert the ones that arent!
#
# **Hint:- https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html**

# %% [markdown]
# ## Scaling your Data!
#
# **Hmmm... something seems off!** Notice the difference between area, bathrooms, and price. Training your data based on these variables will affect your model. Surely there is a way you can fix it!
#
# **Hint:- https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html**

# %% [markdown]
# # Visualizing Your Data

# %% [markdown]
# ## Plotting each parameter to price
#
# As you have noticed, there is one dependent variable (y_variable) and 4 independent variables. In this section, I want you to form a **numpy array** of a pair of variables, i.e
#
# * price Vs area
# * price Vs bedrooms
# * price Vs bathrooms
# * price Vs basement
#
#
#
# ---
#
#
#
# Here, I will do the first one for you:
#
#
#
# ```
# price_area = np.array(pd.DataFrame(X_variables).iloc[:, [1, 0]])
# ```
#
#
#
# ---
#
#
# **Bonus Question: Why did I have to convert it into a pandas dataframe first? Hint: Check the datatype from the previous cell**

# %% [markdown]
# ## Visualizing each parameter individually
# Use a well-known seaborn library to make a scatter plot of all the variables ***except basement***. **Make sure to include axis titles** and use different colours for different variables!
#
# Here, let me do the first one for you!
#
#
#
# ```
# sb.scatterplot(x=price_area[:, 0], y=price_area[:, 1], color="green")
# plt.xlabel("Area")
# plt.ylabel("Price")
# ```

# %% [markdown]
# ### **Intriguing question: Quiz Question 3**
#
# Have you noticed that the scatterplot for bedrooms and bathrooms looks odd? Why is that?:

# %% [markdown]
# # Machine Learning
#
# After looking at the plots, you have decided that the only worthwhile variable to do a regression analysis on is {Fill variable here}. Now you will be moving along to the machine learning portion!

# %% [markdown]
# ## Splitting the data
# Extract the parameter of interest and assign it as X_variable and the price as y_variable

# %% [markdown]
# ## Splitting the data
#
# Okay, we need to split the data into the training and test split in order for us to evaluate the model. Use a train size of 80%
#
# **Hint:- https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html**

# %% [markdown]
# ## Apply Machine Learning to that data
#
# This is the fun part! Apply scikit-learn's linear regression module to train your first ever Machine Learning Model!
#
# **Hint:- https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html**

# %% [markdown]
# ## Testing its accuracy
# Congratulations you have just built your first Machine Learning model! It's time to test it's accuracy. Take your test-data and predict the values.
#
# **Hint:- Use .predict()**

# %% [markdown]
# ## Testing it's accuracy
#
# Okay now that you have predicted the values, time to test the accuracy of your model! Use the mean squared error metric to determine the accuracy of your model!
#
# **Hint:- https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html**

# %% [markdown]
# **Is this a good accuracy? We will get to know in the next section**

# %% [markdown]
# # References
#
# ## Dataset
#
# https://www.kaggle.com/datasets/yasserh/housing-prices-dataset
